# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_community.utilities import SQLDatabase

db = SQLDatabase.from_uri("sqlite:///resources/Chinook.db")

# %%
from langchain.tools import tool

@tool
def sql_query(query: str) -> str:

    """Obtain information from the database using SQL queries"""

    try:
        return db.run(query)
    except Exception as e:
        return f"Error: {e}"

sql_query.invoke("SELECT * FROM Artist LIMIT 10")
# Out:
# "[(1, 'AC/DC'), (2, 'Accept'), (3, 'Aerosmith'), (4, 'Alanis Morissette'), (5, 'Alice In Chains'), (6, 'Antônio Carlos Jobim'), (7, 'Apocalyptica'), (8, 'Audioslave'), (9, 'BackBeat'), (10, 'Billy Cobham')]"

# %%
from langchain.agents import create_agent

agent = create_agent(
    model="gpt-5-nano",
    tools=[sql_query]
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content="Who is the most popular artist beginning with 'S' in this database?")

response = agent.invoke(
    {"messages": [question]}
)

# %%
from pprint import pprint

pprint(response['messages'])
# Out:
# [HumanMessage(content="Who is the most popular artist beginning with 'S' in this database?", additional_kwargs={}, response_metadata={}, id='cea3f9be-eb62-4c48-9ddd-f9bea9e8a6a1'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1050, 'prompt_tokens': 142, 'total_tokens': 1192, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 1024, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E7CoeYOevnZqjLUhuwXQSAAO7tn3v', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fb150-785a-7ae3-b45c-937d83b8d465-0', tool_calls=[{'name': 'sql_query', 'args': {'query': 'SHOW TABLES;'}, 'id': 'call_tAUmD5fNkdylVcsYzql2dWwx', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 142, 'output_tokens': 1050, 'total_tokens': 1192, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 1024}}),
#  ToolMessage(content='Error: (sqlite3.OperationalError) near "SHOW": syntax error\n[SQL: SHOW TABLES;]\n(Background on this error at: https://sqlalche.me/e/20/e3q8)', name='sql_query', id='72ce3cb7-1c16-4092-b90c-7e79052343e5', tool_call_id='call_tAUmD5fNkdylVcsYzql2dWwx'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 616, 'prompt_tokens': 218, 'total_tokens': 834, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E7ColGmhZNHE5DPp7GnlAiafQsYoo', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fb150-974b-7f43-a8fb-1936dbdaf22c-0', tool_calls=[{'name': 'sql_query', 'args': {'query': "SELECT name FROM sqlite_master WHERE type='table' AND name NOT LIKE 'sqlite_%';"}, 'id': 'call_6YRF1aYTZXdO2Y2C8G3Ul0YS', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 218, 'output_tokens': 616, 'total_tokens': 834, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}}),
#  ToolMessage(content="[('Album',), ('Artist',), ('Customer',), ('Employee',), ('Genre',), ('Invoice',), ('InvoiceLine',), ('MediaType',), ('Playlist',), ('PlaylistTrack',), ('Track',)]", name='sql_query', id='e74f1100-20c5-47cf-9637-d63af1ad74bb', tool_call_id='call_6YRF1aYTZXdO2Y2C8G3Ul0YS'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 36, 'prompt_tokens': 311, 'total_tokens': 347, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E7CoqoF0qk0cZd7YxOaAars1a7W1W', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fb150-a8eb-7b62-be71-22b0a403cddc-0', tool_calls=[{'name': 'sql_query', 'args': {'query': 'SELECT DISTINCT Artist.Name FROM Artist INNER JOIN Track ON Artist.ArtistId = Track.ArtistId;'}, 'id': 'call_ae5RzV1SDcNomWY0jvCGZQrb', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 311, 'output_tokens': 36, 'total_tokens': 347, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content='Error: (sqlite3.OperationalError) no such column: Track.ArtistId\n[SQL: SELECT DISTINCT Artist.Name FROM Artist INNER JOIN Track ON Artist.ArtistId = Track.ArtistId;]\n(Background on this error at: https://sqlalche.me/e/20/e3q8)', name='sql_query', id='b44fb906-aa44-4314-9c5a-3b71fc4cb3ce', tool_call_id='call_ae5RzV1SDcNomWY0jvCGZQrb'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 421, 'total_tokens': 444, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E7CosO9XUeLk2veJKUEA9SvBGHgdk', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fb150-af4f-7b53-bb82-64d7719b6cb2-0', tool_calls=[{'name': 'sql_query', 'args': {'query': 'PRAGMA table_info(Artist);'}, 'id': 'call_cgzXLqgdeZvcn5tkoxaXBzP3', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 421, 'output_tokens': 23, 'total_tokens': 444, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content="[(0, 'ArtistId', 'INTEGER', 1, None, 1), (1, 'Name', 'NVARCHAR(120)', 0, None, 0)]", name='sql_query', id='7dd46b55-b2f2-4086-926d-8047283cf877', tool_call_id='call_cgzXLqgdeZvcn5tkoxaXBzP3'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 23, 'prompt_tokens': 493, 'total_tokens': 516, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E7CotqxLhzrasZ4o5vdzwQ0OAhI0R', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fb150-b34d-7421-9051-6105feeed10a-0', tool_calls=[{'name': 'sql_query', 'args': {'query': 'PRAGMA table_info(Track);'}, 'id': 'call_yOccbkOg89rr3qDsr78z8Ygx', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 493, 'output_tokens': 23, 'total_tokens': 516, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}),
#  ToolMessage(content="[(0, 'TrackId', 'INTEGER', 1, None, 1), (1, 'Name', 'NVARCHAR(200)', 1, None, 0), (2, 'AlbumId', 'INTEGER', 0, None, 0), (3, 'MediaTypeId', 'INTEGER', 1, None, 0), (4, 'GenreId', 'INTEGER', 0, None, 0), (5, 'Composer', 'NVARCHAR(220)', 0, None, 0), (6, 'Milliseconds', 'INTEGER', 1, None, 0), (7, 'Bytes', 'INTEGER', 0, None, 0), (8, 'UnitPrice', 'NUMERIC(10,2)', 1, None, 0)]", name='sql_query', id='b0237111-8995-4ac0-99bd-4546bbc3a700', tool_call_id='call_yOccbkOg89rr3qDsr78z8Ygx'),
#  AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 689, 'prompt_tokens': 697, 'total_tokens': 1386, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 576, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E7CouWQmRr1bMf1PAU8VfKNQr8rHu', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019fb150-b7de-7b61-80da-c8b173e94c32-0', tool_calls=[{'name': 'sql_query', 'args': {'query': "SELECT a.Name AS ArtistName, SUM(il.Quantity * il.UnitPrice) AS Revenue\nFROM Artist a\nJOIN Album al ON al.ArtistId = a.ArtistId\nJOIN Track t ON t.AlbumId = al.AlbumId\nJOIN InvoiceLine il ON il.TrackId = t.TrackId\nWHERE a.Name LIKE 'S%'\nGROUP BY a.ArtistId, a.Name\nORDER BY Revenue DESC\nLIMIT 1;"}, 'id': 'call_WsYbGQy3bSpBwAjB1tZaKCgM', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 697, 'output_tokens': 689, 'total_tokens': 1386, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 576}}),
#  ToolMessage(content="[('Smashing Pumpkins', 23.759999999999998)]", name='sql_query', id='8eb095d8-df0a-4212-8753-28da84fe0d2a', tool_call_id='call_WsYbGQy3bSpBwAjB1tZaKCgM'),
#  AIMessage(content="Smashing Pumpkins.\n\nReason: Among artists whose names start with 'S', they have the highest total revenue in the invoices data: 23.76 (in the database's currency). If you want, I can show the full top-10 list or switch to a different popularity metric (e.g., units sold, track count).", additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 525, 'prompt_tokens': 831, 'total_tokens': 1356, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 448, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E7CoyC6IREHiDWElheWr4fy6zKZO5', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019fb150-c9c5-7783-b2fa-cf84701224d5-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 831, 'output_tokens': 525, 'total_tokens': 1356, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 448}})]

# %%
print(response["messages"][-3].tool_calls[0]['args']['query'])
# Out:
# SELECT a.Name AS ArtistName, SUM(il.Quantity * il.UnitPrice) AS Revenue
# FROM Artist a
# JOIN Album al ON al.ArtistId = a.ArtistId
# JOIN Track t ON t.AlbumId = al.AlbumId
# JOIN InvoiceLine il ON il.TrackId = t.TrackId
# WHERE a.Name LIKE 'S%'
# GROUP BY a.ArtistId, a.Name
# ORDER BY Revenue DESC
# LIMIT 1;
