# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain_mcp_adapters.client import MultiServerMCPClient

client = MultiServerMCPClient(
    {
        "travel_server": {
                "transport": "streamable_http",
                "url": "https://mcp.kiwi.com"
            }
    }
)

tools = await client.get_tools()

# %%
from langchain.agents import create_agent
from langgraph.checkpoint.memory import InMemorySaver

agent = create_agent(
    "gpt-5-nano",
    tools=tools,
    checkpointer=InMemorySaver(),
    system_prompt="You are a travel agent. No follow up questions."
)

# %%
from langchain.messages import HumanMessage

config = {"configurable": {"thread_id": "1"}}

response = await agent.ainvoke(
    {"messages": [HumanMessage(content="Get me a direct flight from San Francisco to Tokyo on March 31st")]},
    config
    )

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content='Get me a direct flight from San Francisco to Tokyo on March 31st', additional_kwargs={}, response_metadata={}, id='3a5c952f-247b-43bd-a5f4-6434dfbdeba9'),
#               AIMessage(content='', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1041, 'prompt_tokens': 2505, 'total_tokens': 3546, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 960, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E3z9ifkEnclmE0eY2PaZ4ygKIPFY3', 'service_tier': 'default', 'finish_reason': 'tool_calls', 'logprobs': None}, id='lc_run--019f8391-6d7e-7713-b6e6-79899a71a2f3-0', tool_calls=[{'name': 'search-flight', 'args': {'flyFrom': 'San Francisco', 'flyTo': 'Tokyo', 'departureDate': '31/03/2027', 'departureDateFlexDays': 0, 'returnDate': None, 'adults': 1, 'children': 0, 'infants': 0, 'currency': 'USD', 'locale': 'en', 'max_sector_stopovers': 0}, 'id': 'call_vR9Giu4tXdF8qsN1BqgTBztC', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 2505, 'output_tokens': 1041, 'total_tokens': 3546, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 960}}),
#               ToolMessage(content=[{'type': 'text', 'text': '{\n  "query": "San Francisco → Tokyo on 31/03/2027, 1 adult [≤0 stops/sector]",\n  "currency": "USD",\n  "passengers": {\n    "adults": 1,\n    "children": 0,\n    "infants": 0\n  },\n  "resultsCount": 11,\n  "itineraries": [\n    {\n      "id": "0f9c188451ac0000526d253d_0|0f9c188451ac0000526d253d_1",\n      "price": 470,\n      "priceFormatted": "470 USD",\n      "totalDurationSeconds": 39900,\n      "bookingUrl": "https://kiwi.com/u/d7kj3x",\n      "outbound": {\n        "from": "SFO",\n        "to": "NRT",\n        "departureTime": "2027-03-31T12:20:00",\n        "arrivalTime": "2027-04-01T15:25:00",\n        "durationSeconds": 39900,\n        "stops": 0,\n        "route": [\n          "SFO",\n          "NRT"\n        ],\n        "cabinClass": "Economy",\n        "segments": [\n          {\n            "from": "SFO",\n            "to": "NRT",\n            "fromCity": "San Francisco",\n            "toCity": "Tokyo",\n            "departureTime": "2027-03-31T12:20:00",\n            "arrivalTime": "2027-04-01T15:25:00",\n            "durationSeconds": 39900,\n            "carrier": "NH",\n            "flightNumber": "NH7",\n            "cabinClass": "Economy"\n          }\n        ]\n      },\n      "inbound": null\n    },\n    {\n      "id": "0f9c188451ac0000c8019269_0|0f9c188451ac0000c8019269_1",\n      "price": 1244,\n      "priceFormatted": "1244 USD",\n      "totalDurationSeconds": 40500,\n      "bookingUrl": "https://kiwi.com/u/22jstz",\n      "outbound": {\n        "from": "SFO",\n        "to": "HND",\n        "departureTime": "2027-03-31T01:45:00",\n        "arrivalTime": "2027-04-01T05:00:00",\n        "durationSeconds": 40500,\n        "stops": 0,\n        "route": [\n          "SFO",\n          "HND"\n        ],\n        "cabinClass": "Economy",\n        "segments": [\n          {\n            "from": "SFO",\n            "to": "HND",\n            "fromCity": "San Francisco",\n            "toCity": "Tokyo",\n            "departureTime": "2027-03-31T01:45:00",\n            "arrivalTime": "2027-04-01T05:00:00",\n            "durationSeconds": 40500,\n            "carrier": "NH",\n            "flightNumber": "NH107",\n            "cabinClass": "Economy"\n          }\n        ]\n      },\n      "inbound": null\n    },\n    {\n      "id": "0f9c209f51ac00003f3a153d_0",\n      "price": 1377,\n      "priceFormatted": "1377 USD",\n      "totalDurationSeconds": 40800,\n      "bookingUrl": "https://kiwi.com/u/7umy3g",\n      "outbound": {\n        "from": "SFO",\n        "to": "NRT",\n        "departureTime": "2027-03-31T11:40:00",\n        "arrivalTime": "2027-04-01T15:00:00",\n        "durationSeconds": 40800,\n        "stops": 0,\n        "route": [\n          "SFO",\n          "NRT"\n        ],\n        "cabinClass": "Economy",\n        "segments": [\n          {\n            "from": "SFO",\n            "to": "NRT",\n            "fromCity": "San Francisco",\n            "toCity": "Tokyo",\n            "departureTime": "2027-03-31T11:40:00",\n            "arrivalTime": "2027-04-01T15:00:00",\n            "durationSeconds": 40800,\n            "carrier": "UA",\n            "flightNumber": "UA837",\n            "cabinClass": "Economy"\n          }\n        ]\n      },\n      "inbound": null\n    },\n    {\n      "id": "0f9c209f51ac0000f167eadf_0",\n      "price": 1385,\n      "priceFormatted": "1385 USD",\n      "totalDurationSeconds": 40800,\n      "bookingUrl": "https://kiwi.com/u/t2d6zt",\n      "outbound": {\n        "from": "SFO",\n        "to": "NRT",\n        "departureTime": "2027-03-31T11:40:00",\n        "arrivalTime": "2027-04-01T15:00:00",\n        "durationSeconds": 40800,\n        "stops": 0,\n        "route": [\n          "SFO",\n          "NRT"\n        ],\n        "cabinClass": "Economy",\n        "segments": [\n          {\n            "from": "SFO",\n            "to": "NRT",\n            "fromCity": "San Francisco",\n            "toCity": "Tokyo",\ ...
#               AIMessage(content='Here are the direct (non-stop) options for a one-way flight from San Francisco (SFO) to Tokyo on March 31, 2027. All are direct with 0 stops.\n\n| Itinerary | Route | Times (local) | Cabin | Price | Booking |\n|---|---|---|---|---|---|\n| Cheapest direct | SFO → NRT (NH7) | 31 Mar 12:20 → 01 Apr 15:25 (11h 5m) | Economy | 470 USD | https://kiwi.com/u/d7kj3x |\n| Shortest direct | SFO → NRT (NH7) | 31 Mar 12:20 → 01 Apr 15:25 (11h 5m) | Economy | 470 USD | https://kiwi.com/u/d7kj3x |\n| Notable: NH7013 direct | SFO → NRT (NH7013) | 31 Mar 11:40 → 01 Apr 15:00 (11h 20m) | Economy | 1385 USD | https://kiwi.com/u/t2d6zt |\n| Notable: UA837 direct | SFO → NRT (UA837) | 31 Mar 11:40 → 01 Apr 15:00 (11h 20m) | Economy | 1377 USD | https://kiwi.com/u/7umy3g |\n| Notable: NH7 direct (alternative time) | SFO → NRT (NH7) | 31 Mar 12:20 → 01 Apr 15:25 (11h 5m) | Economy | 470 USD | https://kiwi.com/u/d7kj3x |\n| Notable: SFO → HND direct | SFO → HND (UA875) | 31 Mar 10:25 → 01 Apr 13:55 (11h 30m) | Economy | 1430 USD | https://kiwi.com/u/4tmcg4 |\n| Notable: SFO → HND direct (NH7011) | SFO → HND (NH7011) | 31 Mar 01:45 → 01 Apr 05:00 (11h 15m) | Economy | 1449 USD | https://kiwi.com/u/uz8dk3 |\n\nBest price: 470 USD (NH7 direct SFO → NRT)\nShortest duration: 11h 5m (NH7 direct SFO → NRT)\n\nRecommendation: Book the cheapest direct option (NH7 SFO → NRT) at 470 USD if you want the best price with a direct flight. Booking links are above.\n\nFun fact: Tokyo blends ultramodern skyscrapers with traditional temples, and it’s famous for its punctual, ultra-efficient transit system—perfect for hopping between neighborhoods in a single day. Enjoy your trip!', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 6189, 'prompt_tokens': 6057, 'total_tokens': 12246, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 5568, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 2304}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E3z9uvqJpmN8DoNHimjmg3N0gjsSs', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f8391-9bc4-77a2-bab8-8f9fe357bbd9-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 6057, 'output_tokens': 6189, 'total_tokens': 12246, 'input_token_details': {'audio': 0, 'cache_read': 2304}, 'output_token_details': {'audio': 0, 'reasoning': 5568}})]}

# %%
print(response["messages"][-1].content)
# Out:
# Here are the direct (non-stop) options for a one-way flight from San Francisco (SFO) to Tokyo on March 31, 2027. All are direct with 0 stops.
#
# | Itinerary | Route | Times (local) | Cabin | Price | Booking |
# |---|---|---|---|---|---|
# | Cheapest direct | SFO → NRT (NH7) | 31 Mar 12:20 → 01 Apr 15:25 (11h 5m) | Economy | 470 USD | https://kiwi.com/u/d7kj3x |
# | Shortest direct | SFO → NRT (NH7) | 31 Mar 12:20 → 01 Apr 15:25 (11h 5m) | Economy | 470 USD | https://kiwi.com/u/d7kj3x |
# | Notable: NH7013 direct | SFO → NRT (NH7013) | 31 Mar 11:40 → 01 Apr 15:00 (11h 20m) | Economy | 1385 USD | https://kiwi.com/u/t2d6zt |
# | Notable: UA837 direct | SFO → NRT (UA837) | 31 Mar 11:40 → 01 Apr 15:00 (11h 20m) | Economy | 1377 USD | https://kiwi.com/u/7umy3g |
# | Notable: NH7 direct (alternative time) | SFO → NRT (NH7) | 31 Mar 12:20 → 01 Apr 15:25 (11h 5m) | Economy | 470 USD | https://kiwi.com/u/d7kj3x |
# | Notable: SFO → HND direct | SFO → HND (UA875) | 31 Mar 10:25 → 01 Apr 13:55 (11h 30m) | Economy | 1430 USD | https://kiwi.com/u/4tmcg4 |
# | Notable: SFO → HND direct (NH7011) | SFO → HND (NH7011) | 31 Mar 01:45 → 01 Apr 05:00 (11h 15m) | Economy | 1449 USD | https://kiwi.com/u/uz8dk3 |
#
# Best price: 470 USD (NH7 direct SFO → NRT)
# Shortest duration: 11h 5m (NH7 direct SFO → NRT)
#
# Recommendation: Book the cheapest direct option (NH7 SFO → NRT) at 470 USD if you want the best price with a direct flight. Booking links are above.
#
# Fun fact: Tokyo blends ultramodern skyscrapers with traditional temples, and it’s famous for its punctual, ultra-efficient transit system—perfect for hopping between neighborhoods in a single day. Enjoy your trip!
