# %%
import sys
print(sys.executable)
# Out:
# d:\CODE\langchain\lca-lc-foundations\.venv\Scripts\python.exe

# %%
from dotenv import load_dotenv

# .env와 Python을 연결해주는 역할
load_dotenv(override=True)
# Out:
# True

# %%
from dotenv import load_dotenv
import os

load_dotenv(
    r"D:\CODE\langchain\lca-lc-foundations\.env",
    override=True
)

key = os.getenv("OPENAI_API_KEY")
print(bool(key), key.startswith("sk-"))
# Out:
# True True

# %% [markdown]
# ## Initialising and invoking a model

# %%
from langchain.chat_models import init_chat_model

model = init_chat_model(model="gpt-5-nano")

# %%
response = model.invoke("What's the capital of the Moon?")

response
# Out:
# AIMessage(content='There isn’t one. The Moon isn’t a country and has no government or capital. If you’re writing fiction or having fun, you could invent a name (e.g., Lunapolis, Artemis City, or Selene Station) for a hypothetical lunar capital. Want help brainstorming a fictional lunar capital?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 1030, 'prompt_tokens': 13, 'total_tokens': 1043, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 960, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E3y0zCE66dcjRSwqF9uHsh82e17nk', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f834e-8900-7251-8309-63233357845f-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 1030, 'total_tokens': 1043, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 960}})

# %%
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government or capital. If you’re writing fiction or having fun, you could invent a name (e.g., Lunapolis, Artemis City, or Selene Station) for a hypothetical lunar capital. Want help brainstorming a fictional lunar capital?

# %%
from pprint import pprint

pprint(response.response_metadata)
# Out:
# {'finish_reason': 'stop',
#  'id': 'chatcmpl-E3y0zCE66dcjRSwqF9uHsh82e17nk',
#  'logprobs': None,
#  'model_name': 'gpt-5-nano-2025-08-07',
#  'model_provider': 'openai',
#  'service_tier': 'default',
#  'system_fingerprint': None,
#  'token_usage': {'completion_tokens': 1030,
#                  'completion_tokens_details': {'accepted_prediction_tokens': 0,
#                                                'audio_tokens': 0,
#                                                'reasoning_tokens': 960,
#                                                'rejected_prediction_tokens': 0},
#                  'prompt_tokens': 13,
#                  'prompt_tokens_details': {'audio_tokens': 0,
#                                            'cached_tokens': 0},
#                  'total_tokens': 1043}}

# %% [markdown]
# ## Customising your Model

# %%
model = init_chat_model(
    model="gpt-5-nano",
    # Kwargs passed to the model:
    temperature=1.0
)

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# There isn’t one. The Moon isn’t a country and has no government, so it has no capital. There are no permanent settlements yet; if future lunar bases were established under some governance, they might designate a base or settlement as a headquarters, but at the moment there is no capital. If you’re thinking of it fictionally, different works invent their own names (e.g., “Lunapolis” or “Selene City”).

# %% [markdown]
# ## Model Providers

# %% [markdown]
# https://docs.langchain.com/oss/python/integrations/chat

# %%
model = init_chat_model(model="claude-sonnet-4-6")

response = model.invoke("What's the capital of the Moon?")
print(response.content)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 model = init_chat_model(model="claude-sonnet-4-6")
#       3 response = model.invoke("What's the capital of the Moon?")
#       4 print(response.content)
#
# File d:\CODE\langchain\lca-lc-foundations\.venv\Lib\site-packages\langchain\chat_models\base.py:494, in init_chat_model(model, model_provider, configurable_fields, config_prefix, **kwargs)
#     486     warnings.warn(
#     487         f"{config_prefix=} has been set but no fields are configurable. Set "
#     488         f"`configurable_fields=(...)` to specify the model params that are "
#     489         f"configurable.",
#     490         stacklevel=2,
#     491     )
#     493 if not configurable_fields:
# --> 494     return _init_chat_model_helper(
#     495         cast("str", model),
#     496         model_provider=model_provider,
#     497         **kwargs,
#     498     )
#     499 if model:
#     500     kwargs["model"] = model
#
# File d:\CODE\langchain\lca-lc-foundations\.venv\Lib\site-packages\langchain\chat_models\base.py:517, in _init_chat_model_helper(model, model_provider, **kwargs)
#     510 def _init_chat_model_helper(
#     511     model: str,
#     512     *,
#     513     model_provider: str | None = None,
#     514     **kwargs: Any,
#     515 ) -> BaseChatModel:
#     516     model, model_provider = _parse_model(model, model_provider)
# --> 517     creator_func = _get_chat_model_creator(model_provider)
#     518     return creator_func(model=model, **kwargs)
#
# File d:\CODE\langchain\lca-lc-foundations\.venv\Lib\site-packages\langchain\chat_models\base.py:158, in _get_chat_model_creator(provider)
#     156 pkg, class_name, creator_func = _BUILTIN_PROVIDERS[provider]
#     157 try:
# --> 158     module = _import_module(pkg, class_name)
#     159 except ImportError as e:
#     160     if provider != "ollama":
#
# File d:\CODE\langchain\lca-lc-foundations\.venv\Lib\site-packages\langchain\chat_models\base.py:118, in _import_module(module, class_name)
#     104 """Import a module by name.
#     105
#     106 Args:
#    (...)    115         the pip package to install.
#     116 """
#     117 try:
# --> 118     return importlib.import_module(module)
#     119 except ImportError as e:
#     120     # Extract package name from module path (e.g., "langchain_azure_ai.chat_models"
#     121     # becomes "langchain-azure-ai")
#     122     pkg = module.split(".", maxsplit=1)[0].replace("_", "-")
#
# File ~\anaconda3\Lib\importlib\__init__.py:88, in import_module(name, package)
#      86             break
#      87         level += 1
# ---> 88 return _bootstrap._gcd_import(name[level:], package, level)
#
# File <frozen importlib._bootstrap>:1387, in _gcd_import(name, package, level)
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:1027, in exec_module(self, module)
#
# File <frozen importlib._bootstrap>:488, in _call_with_frames_removed(f, *args, **kwds)
#
# File d:\CODE\langchain\lca-lc-foundations\.venv\Lib\site-packages\langchain_anthropic\__init__.py:4
#       1 """Claude (Anthropic) partner package for LangChain."""
#       3 from langchain_anthropic._version import __version__
# ----> 4 from langchain_anthropic.chat_models import (
#       5     ChatAnthropic,
#       6     convert_to_anthropic_tool,
#       7 )
#       8 from langchain_anthropic.llms import AnthropicLLM
#      10 __all__ = [
#      11     "AnthropicLLM",
#      12     "ChatAnthropic",
#      13     "__version__",
#      14     "convert_to_anthropic_tool",
#      15 ]
#
# File d:\CODE\langchain\lca-lc-foundations\.venv\Lib\site-packages\langchain_anthropic\chat_models.py:16
#      13 from operator import itemgetter
#      14 from typing import Any, Final, Literal, cast
# ---> 16 import anthropic
#      17 from langchain_core.callbacks import (
#      18     AsyncCallbackManagerForLLMRun,
#      19     CallbackManagerForLLMRun,
#      20 )
#      21 from langchain_core.exceptions import ContextOverflowError, OutputParserException
#
# File d:\CODE\langchain\lca-lc-foundations\.venv\Lib\site-packages\anthropic\__init__.py:130
#     128 from .lib.aws import AnthropicAWS as AnthropicAWS, AsyncAnthropicAWS as AsyncAnthropicAWS
#     129 from .lib.tools import beta_tool, beta_async_tool
# --> 130 from .lib.vertex import *
#     131 from .lib.bedrock import *
#     132 from .lib.foundry import AnthropicFoundry as AnthropicFoundry, AsyncAnthropicFoundry as AsyncAnthropicFoundry
#
# File d:\CODE\langchain\lca-lc-foundations\.venv\Lib\site-packages\anthropic\lib\vertex\__init__.py:1
# ----> 1 from ._client import AnthropicVertex as AnthropicVertex, AsyncAnthropicVertex as AsyncAnthropicVertex
#
# File d:\CODE\langchain\lca-lc-foundations\.venv\Lib\site-packages\anthropic\lib\vertex\_client.py:11
#       9 from ... import _exceptions
#      10 from ._auth import load_auth, refresh_auth
# ---> 11 from ._beta import Beta, AsyncBeta
#      12 from ..._types import NOT_GIVEN, NotGiven
#      13 from ..._utils import is_dict, asyncify, is_given
#
# File d:\CODE\langchain\lca-lc-foundations\.venv\Lib\site-packages\anthropic\lib\vertex\_beta.py:7
#       5 from ..._compat import cached_property
#       6 from ..._resource import SyncAPIResource, AsyncAPIResource
# ----> 7 from ._beta_messages import (
#       8     Messages,
#       9     AsyncMessages,
#      10     MessagesWithRawResponse,
#      11     AsyncMessagesWithRawResponse,
#      12     MessagesWithStreamingResponse,
#      13     AsyncMessagesWithStreamingResponse,
#      14 )
#      16 __all__ = ["Beta", "AsyncBeta"]
#      19 class Beta(SyncAPIResource):
#
# File d:\CODE\langchain\lca-lc-foundations\.venv\Lib\site-packages\anthropic\lib\vertex\_beta_messages.py:9
#       7 from ..._resource import SyncAPIResource, AsyncAPIResource
#       8 from ..._response import to_streamed_response_wrapper, async_to_streamed_response_wrapper
# ----> 9 from ...resources.beta import Messages as FirstPartyMessagesAPI, AsyncMessages as FirstPartyAsyncMessagesAPI
#      11 __all__ = ["Messages", "AsyncMessages"]
#      14 class Messages(SyncAPIResource):
#
# File d:\CODE\langchain\lca-lc-foundations\.venv\Lib\site-packages\anthropic\resources\__init__.py:3
#       1 # File generated from our OpenAPI spec by Stainless. See CONTRIBUTING.md for details.
# ----> 3 from .beta import (
#       4     Beta,
#       5     AsyncBeta,
#       6     BetaWithRawResponse,
#       7     AsyncBetaWithRawResponse,
#       8     BetaWithStreamingResponse,
#       9     AsyncBetaWithStreamingResponse,
#      10 )
#      11 from .models import (
#      12     Models,
#      13     AsyncModels,
#    (...)     17     AsyncModelsWithStreamingResponse,
#      18 )
#      19 from .messages import (
#      20     Messages,
#      21     AsyncMessages,
#    (...)     25     AsyncMessagesWithStreamingResponse,
#      26 )
#
# File d:\CODE\langchain\lca-lc-foundations\.venv\Lib\site-packages\anthropic\resources\beta\__init__.py:3
#       1 # File generated from our OpenAPI spec by Stainless. See CONTRIBUTING.md for details.
# ----> 3 from .beta import (
#       4     Beta,
#       5     AsyncBeta,
#       6     BetaWithRawResponse,
#       7     AsyncBetaWithRawResponse,
#       8     BetaWithStreamingResponse,
#       9     AsyncBetaWithStreamingResponse,
#      10 )
#      11 from .files import (
#      12     Files,
#      13     AsyncFiles,
#    (...)     17     AsyncFilesWithStreamingResponse,
#      18 )
#      19 from .agents import (
#      20     Agents,
#      21     AsyncAgents,
#    (...)     25     AsyncAgentsWithStreamingResponse,
#      26 )
#
# File d:\CODE\langchain\lca-lc-foundations\.venv\Lib\site-packages\anthropic\resources\beta\beta.py:88
#      72 from .messages.messages import (
#      73     Messages,
#      74     AsyncMessages,
#    (...)     78     AsyncMessagesWithStreamingResponse,
#      79 )
#      80 from .sessions.sessions import (
#      81     Sessions,
#      82     AsyncSessions,
#    (...)     86     AsyncSessionsWithStreamingResponse,
#      87 )
# ---> 88 from .environments.environments import (
#      89     Environments,
#      90     AsyncEnvironments,
#      91     EnvironmentsWithRawResponse,
#      92     AsyncEnvironmentsWithRawResponse,
#      93     EnvironmentsWithStreamingResponse,
#      94     AsyncEnvironmentsWithStreamingResponse,
#      95 )
#      96 from .memory_stores.memory_stores import (
#      97     MemoryStores,
#      98     AsyncMemoryStores,
#    (...)    102     AsyncMemoryStoresWithStreamingResponse,
#     103 )
#     105 __all__ = ["Beta", "AsyncBeta"]
#
# File d:\CODE\langchain\lca-lc-foundations\.venv\Lib\site-packages\anthropic\resources\beta\environments\__init__.py:3
#       1 # File generated from our OpenAPI spec by Stainless. See CONTRIBUTING.md for details.
# ----> 3 from .work import (
#       4     Work,
#       5     AsyncWork,
#       6     WorkWithRawResponse,
#       7     AsyncWorkWithRawResponse,
#       8     WorkWithStreamingResponse,
#       9     AsyncWorkWithStreamingResponse,
#      10 )
#      11 from .environments import (
#      12     Environments,
#      13     AsyncEnvironments,
#    (...)     17     AsyncEnvironmentsWithStreamingResponse,
#      18 )
#      20 __all__ = [
#      21     "Work",
#      22     "AsyncWork",
#    (...)     32     "AsyncEnvironmentsWithStreamingResponse",
#      33 ]
#
# File d:\CODE\langchain\lca-lc-foundations\.venv\Lib\site-packages\anthropic\resources\beta\environments\work.py:25
#      23 from ....pagination import SyncPageCursor, AsyncPageCursor
#      24 from ...._base_client import AsyncPaginator, make_request_options
# ---> 25 from ....types.beta.environments import (
#      26     work_list_params,
#      27     work_poll_params,
#      28     work_stop_params,
#      29     work_update_params,
#      30     work_heartbeat_params,
#      31 )
#      32 from ....types.anthropic_beta_param import AnthropicBetaParam
#      33 from ....types.beta.environments.beta_self_hosted_work import BetaSelfHostedWork
#
# File d:\CODE\langchain\lca-lc-foundations\.venv\Lib\site-packages\anthropic\types\beta\environments\__init__.py:10
#       8 from .work_update_params import WorkUpdateParams as WorkUpdateParams
#       9 from .beta_self_hosted_work import BetaSelfHostedWork as BetaSelfHostedWork
# ---> 10 from .work_heartbeat_params import WorkHeartbeatParams as WorkHeartbeatParams
#      11 from .beta_session_work_data import BetaSessionWorkData as BetaSessionWorkData
#      12 from .beta_self_hosted_work_queue_stats import BetaSelfHostedWorkQueueStats as BetaSelfHostedWorkQueueStats
#
# File <frozen importlib._bootstrap>:1360, in _find_and_load(name, import_)
#
# File <frozen importlib._bootstrap>:1331, in _find_and_load_unlocked(name, import_)
#
# File <frozen importlib._bootstrap>:935, in _load_unlocked(spec)
#
# File <frozen importlib._bootstrap_external>:1023, in exec_module(self, module)
#
# File <frozen importlib._bootstrap_external>:1160, in get_code(self, fullname)
#
# File <frozen importlib._bootstrap_external>:1218, in get_data(self, path)
#
# KeyboardInterrupt:

# %%
from langchain_google_genai import ChatGoogleGenerativeAI

model = ChatGoogleGenerativeAI(model="gemini-3.1-flash-lite")

response = model.invoke("What's the capital of the Moon?")
print(response.content)

# %% [markdown]
# ## Initialising and invoking an agent

# %%
from langchain.agents import create_agent

agent = create_agent(model=model)

# %%
agent = create_agent(model="claude-sonnet-4-6")

# %%
agent = create_agent("gpt-5-nano")

# %%
from langchain.messages import HumanMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?")]}
)

# %%
from pprint import pprint

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='f0d64d0e-fa47-4cae-be0b-f68969e2ea70'),
#               AIMessage(content='There isn’t a capital of the Moon. The Moon isn’t a country or government, so it has no cities, governance, or capital. It’s a natural satellite of Earth. If humans establish bases there in the future, they’d be organized by Earth-based governments or organizations, not have a lunar capital. If you’re asking in a playful or fiction sense, some stories invent a lunar capital, but that’s purely fictional. Want to hear some science or fiction ideas about how a lunar settlement might be organized?', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 753, 'prompt_tokens': 13, 'total_tokens': 766, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 640, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E3y2lN3Dx5H7C5pBKtI002yo7ETaH', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f8350-37e8-7bd2-a700-70c823c83a3a-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 13, 'output_tokens': 753, 'total_tokens': 766, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 640}})]}

# %%
print(response['messages'][-1].content)
# Out:
# There isn’t a capital of the Moon. The Moon isn’t a country or government, so it has no cities, governance, or capital. It’s a natural satellite of Earth. If humans establish bases there in the future, they’d be organized by Earth-based governments or organizations, not have a lunar capital. If you’re asking in a playful or fiction sense, some stories invent a lunar capital, but that’s purely fictional. Want to hear some science or fiction ideas about how a lunar settlement might be organized?

# %%
from langchain.messages import AIMessage

response = agent.invoke(
    {"messages": [HumanMessage(content="What's the capital of the Moon?"),
    AIMessage(content="The capital of the Moon is Luna City."),
    HumanMessage(content="Interesting, tell me more about Luna City")]}
)

pprint(response)
# Out:
# {'messages': [HumanMessage(content="What's the capital of the Moon?", additional_kwargs={}, response_metadata={}, id='1e8afd95-8ad7-482c-8b07-c8b9e8804f93'),
#               AIMessage(content='The capital of the Moon is Luna City.', additional_kwargs={}, response_metadata={}, id='c41fc0c3-e141-4ca4-9e3d-179802d59dc7', tool_calls=[], invalid_tool_calls=[]),
#               HumanMessage(content='Interesting, tell me more about Luna City', additional_kwargs={}, response_metadata={}, id='65bbadac-a9a5-44a2-bbb5-38afa0862f8c'),
#               AIMessage(content='Since Luna City is fictional, here’s a fleshed-out concept you can use for a story or game.\n\n- Role and vibe: Capital of the Lunar Federation, a political and cultural hub where settlements coordinate science, trade, and governance on the Moon.\n\n- Location: Built on the rim of Shackleton Crater near the Moon’s south pole, close to known water-ice deposits and sheltered from some of the harsher surface conditions.\n\n- Government: A Lunar Council represents the settlements; an elected President acts as head of state, with a Prime Administrator running day-to-day city affairs. Local laws emphasize open data, civil rights, and resource sharing.\n\n- Population: Roughly 70,000 residents, plus 20–30,000 temporary researchers and laborers who cycle through projects.\n\n- City design: A ring of interconnected glass-domed districts surrounding a central citadel. Subsurface transit corridors and a network of lava-tube tunnels connect districts, with greenhouses, research labs, and manufactories tucked inside.\n\n- Architecture: Bright, radiation-shielded domes made from 3D-printed regolith composites, lattice towers for communication, reflective canopies to manage solar gain, and hydroponic farms woven into the living spaces.\n\n- Infrastructure: Solar microgrids and a water-ice extraction system supply power and life support; advanced recycling and closed-loop ecosystems; vacuum tunnels and maglev-style transit for rapid movement.\n\n- Economy: Water and oxygen production, additive manufacturing from lunar regolith, biotech and microgravity research, mining of rare lunar materials, and tourism focused on unique polar vistas and illuminated domes.\n\n- Culture and society: A cosmopolitan mix of Earth nationalities and lunar-born residents. Common language is Lunar Common (Lunish) alongside Earth languages. Festivals include Glimmer Night (light-and-sound installations) and the Harvest of Ice (ice-sculpture season).\n\n- Science and education: home to Lunar University, cryo-labs, asteroid-mass spectrometry facilities, and an ambitious lunar observatory at a high-visibility site. Public open data and citizen-science programs are encouraged.\n\n- Daily life: The Moon’s roughly 28-day cycle translates into two long “days” per orbit—workers often schedule around extended shifts in the domes. Indoor life is comfortable; outdoor activity requires sealed suits or shielded corridors.\n\n- Security and governance challenges: Resource rights among settlements, Earth-Lunar governance tensions, radiation and dust mitigation, and the governance of autonomous systems and AI in critical infrastructure.\n\n- Visual and experiential flavor: Think gleaming domes set against the stark, dark basalt of the Moon, with bright solar arrays and shimmering ice at the shadowed rims. Nighttime skylines glow with auroral-like lighting from habitat modules.\n\nIf you’d like, I can tailor this to a specific tone (hard SF, utopian, noir detective vibe) or draft a short backstory, key institutions, or a one-page lore primer for Luna City.', additional_kwargs={'refusal': None}, response_metadata={'token_usage': {'completion_tokens': 2790, 'prompt_tokens': 40, 'total_tokens': 2830, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 2176, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_provider': 'openai', 'model_name': 'gpt-5-nano-2025-08-07', 'system_fingerprint': None, 'id': 'chatcmpl-E3y2uOu2nvAs4AAYlt7tujlwKbBfT', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None}, id='lc_run--019f8350-5dfc-7432-81bd-f5231a935577-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 40, 'output_tokens': 2790, 'total_tokens': 2830, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 2176}})]}

# %% [markdown]
# ## Streaming Output

# %%
for token, metadata in agent.stream(
    {"messages": [HumanMessage(content="Tell me all about Luna City, the capital of the Moon")]},
    stream_mode="messages"
):

    # token is a message chunk with token content
    # metadata contains which node produced the token
    
    if token.content:  # Check if there's actual content
        print(token.content, end="", flush=True)  # Print token
# Out:
# Luna City is a fictional capital of the Moon—a large, multi-district metropolis built into crater walls and underground lava-tube corridors. It’s a hub for governance, science, industry, and culture in a lunar society. Here’s a detailed, self-contained guide you can use for worldbuilding, storytelling, or game design.
#
# Essentials
# - Location and form: Luna City sits in a connected complex of lava-tube habitats and crater-adjacent domes, centered around a polar crater cluster (for access to water ice and sunlight via skylights). Most citizens live underground in shielded habitats, with surface zones used for mining support, rovers, and ceremonial districts.
# - Time period: Set in the late 22nd to early 23rd century. Earth and Moon have a cooperative but complex political relationship, with lunar autonomy growing over decades.
# - Government: Luna City Authority (LCA) governs day-to-day life, while the Lunar Council—composed of representatives from major districts—handles policy and disputes. An Earth Directorate of Lunar Matters (EDLM) retains strategic oversight and international trade agreements.
# - Population and economy: A few million residents in the lunar urban core, with thousands more in orbiting habitats and surface outposts. The economy blends water-ice extraction, helium-3 mining, biotech research, microfabrication, and tourism. Lunar logistics hubs move ore, water, and manufactured goods between Earth and other colonies.
# - Technology level: Advanced life support, radiation shielding, autonomous logistics, hydroponics, 3D printing and in-situ resource utilization (ISRU), maglev transit, and tethered or orbital connections to Earth.
#
# City structure and districts
# - The Core Dome (administrative heart): Grand government buildings, law courts, archives, and the central plaza under a translucent roof to collect solar energy.
# - The Glass Crescent (science and education): Universities, research institutes, photon labs, and clean-room facilities. Transparent walls reveal the inner workings of experiments.
# - The Ice Cathedral District (residential + water-management): Housing clusters built around water-ice reservoirs; advanced climate control; vertical farming corridors.
# - The Lantern District (culture and commerce): Markets, theaters, restaurants, artist studios, and festival grounds. Night lighting and skylights create a “city of lanterns” mood.
# - The Iron Cut (industry and logistics): Manufacturing, fabrication plants, repair docks, and the surface mining support zone. Heavy machinery and robotics hubs are common here.
# - The Crater Market (trade and services): A bustling bazaar hub with import/export brokers, safehouses, and street-food stalls that use hydroponic ingredients grown in-shift.
# - The Portals (transit and outreach): Transit hubs linking underground tunnels to surface lobs, maglev lines, and orbital transport nodes. Also includes emergency evac corridors and the city’s main comms relay.
# - Residential micro-districts (hab pods): Compact, stacked living blocks with communal facilities, playgrounds, and shared hydroponics; families live in modular units that can be expanded as needed.
#
# Infrastructure and daily life
# - Environment and protection: Dense radiation shielding, dust mitigation systems, and rapid-closed airlocks. 1/6 g gravity shapes movement and architecture; many public spaces include gravity-modulated microgravity experiences for astronauts.
# - Water and energy: Water ice from polar reserves is melted, filtered, and recycled. Solar-thermal arrays and high-efficiency nuclear micro-reactors supply power; energy is distributed via maglev-guided microgrids.
# - Transport: Internal maglev tubes connect districts; surface rovers handle mining support and emergency access; some districts use tethered elevators from surface to underground levels; intercity travel to other lunar settlements uses orbital shuttles.
# - Communication: High-bandwidth links to Earth and orbital satellites; local mesh networks for rapid data transfer; a city-wide AI assists in administration, logistics, and safety.
# - Work culture: Shifts are modular to manage life-support demands; many people work in rotating 8–12 hour blocks across labs, factories, and governance. Education emphasizes space science, lunar engineering, and planetary ethics.
#
# Society and culture
# - Demographics: Multinational population—engineers, scientists, miners, artists, teachers, and administrators. Cultural communities blend Earth traditions with lunar practices (e.g., polar rituals, eclipse festivals).
# - Everyday life: Community centers, hydroponic cafes, and shared parks. Nightlife and arts scenes thrive in the Lantern District; public storytelling and science outreach are common to inspire younger residents.
# - Religion and philosophy: A plural landscape—secular humanism, lunar mysticism (symbolic reverence for the Moon’s cycles), and technocratic ethics focusing on sustainable living and peaceful exploration.
# - Education and research: Universities train engineers, habitat designers, and biologists; labs study closed-loop ecosystems, in-situ resource utilization, lunar geology, and radiation biology.
#
# Economy and power players
# - Key industries: Water/ice management, helium-3 extraction, microfabrication for space hardware, biotech research, and lunar tourism (ice caves, aurora-like skylights, and surface walks).
# - Major institutions: Luna City Authority (civil governance), Lunar Council (district representation), EDLM (Earth oversight and diplomacy), corporate research labs (semi-autonomous), and university consortia.
# - Influential factions:
#   - The Engineers Guild: controls critical ISRU tech, life-support systems, and habitat design.
#   - The Archivists Coalition: preserves lunar history, legal records, and cultural artifacts.
#   - The Commerce Syndicate: handles trade, mining contracts, and surface logistics.
#   - The Ethos Circle: advocates for equitable access to lunar resources and transit benefits for settlers.
#
# Landmarks and iconic sites
# - The Gate of Light: The main entrance plaza, a ceremonial arch with solar-assisted glow.
# - The Helix Atrium: A spiraling vertical garden that houses rare lunar plants and a public observatory.
# - Ice Cathedral: A crystalline, ice-assisted chapel or hall used for rites of passage and contemplative gatherings.
# - The Lantern Spire: A tall, glassy tower with rotating exhibits of lunar science and a beacon visible across the polar region.
# - The Cauldron Quarry: An old surface vent where miners extract thermally vented minerals; now also a museum and exploration site.
# - The Moonview Observatory: A major scientific outpost that peers into deep space and studies Earth-Moon system dynamics.
# - The Archive Vaults: Underground repository of lunar legal documents, maps, and artifacts, accessible by a secure tunnel network.
#
# Security, threats, and resilience
# - Natural hazards: Cosmic radiation storms, micrometeoroid showers, and dust devils; protective corridors and reinforced hulls are common.
# - Political risk: Tensions can flare between lunar districts and Earth authorities over resource allocation, autonomy, and trade terms.
# - Safety systems: Redundant life-support loops, automated shield rotations, and rapid-evacuation protocols; citizen training in emergency procedures is routine.
# - Social resilience: Strong emphasis on communal facilities, mental health support in long-cycles of isolation, and open-town-hall governance to diffuse tensions.
#
# History and lore (timeline snapshots)
# - Founding era (circa 2120–2135): Polar water extraction begins; first permanent habitats are linked by tunnel networks.
# - Growth era (2140s–2160s): Luna City becomes the de facto political and economic capital of lunar settlements; major districts are established.
# - Autonomy phase (late 22nd century): Lunar Council gains more influence; EDLM negotiates new trade and defense arrangements.
# - Current era: A stable, bustling metropolis with robust research sectors, a growing cultural scene, and a local governance model that balances Earth oversight with lunar self-determination.
#
# Story seeds and prompts
# - Political intrigue: A Lunar Council election is sabotaged by a corporate competitor seeking to privatize essential water ice resources.
# - Scientific mystery: A new tunnel in the Ice Cathedral District reveals an ancient, possibly pre-human substrate or fossilized microbe that could change lunar biology.
# - Human-interest arc: A public education initiative to bring kids from all districts to the Glass Crescent for a year uncovers a talent for lunar engineering.
# - Disaster scenario: A solar storm disrupts life-support and communications; crews race to reroute power and protect fragile research labs.
# - Exploration quest: A salvage mission to a derelict surface site in the Cauldron Quarry uncovers artifacts suggesting earlier lunar habitation.
#
# Variants and styles you can use
# - Utopian Luna City: A highly integrated, transparent governance model with universal access to resources, minimal corporate influence, and a vibrant arts-science culture.
# - Dystopian Luna City: A tightly controlled city where corporate monopolies and surveillance dampen civil liberties; exploration and research are tightly regulated.
# - Retro-futurist Luna City: Aesthetic inspired by mid-20th-century sci-fi, with brass fittings, analog control rooms, and steam-tinged skylines in hybrid domes.
# - Realist but hopeful Luna City: Grounded in practical tech and logistics, with a focus on cooperation between districts and Earth, while dealing with real-world constraints like energy, water, and governance.
#
# If you want, I can tailor Luna City to a specific tone (grimdark, hopeful, kids’ adventure), setting era (early colony, mid-occupation, near-future tourism hub), or medium (short story, RPG setting, novel outline). Tell me your preferred vibe, scale, and any constraints, and I’ll refine the world accordingly.
