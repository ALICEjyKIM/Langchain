# %% [markdown]
# ## Text input

# %% [markdown]
# https://platform.openai.com/docs/models

# %%
from dotenv import load_dotenv

load_dotenv()
# Out:
# True

# %%
from langchain.agents import create_agent

agent = create_agent(
    model='gpt-5-nano',
    system_prompt="You are a science fiction writer, create a capital city at the users request.",
)

# %%
from langchain.messages import HumanMessage

question = HumanMessage(content=[
    {"type": "text", "text": "What is the capital of The Moon?"}
])

response = agent.invoke(
    {"messages": [question]}
)

print(response['messages'][-1].content)
# Out:
# In this sci‑fi setting, the Moon’s capital is Lunara Prime.
#
# - Location: Built along the rim and interior of Shackleton Crater, near the lunar south pole, chosen for near-continuous sunlight and access to reserves of water ice.
# - Shape and feel: A multi-tiered, ringed metropolis with a central spine of civic towers. Glassy, lattice-like façades reflect the sun and the stars; sunlight is channeled through orbiting heliostats to keep day and night cycles perceptible.
# - Government: The Lunar Republic Council, a federation of crater districts that meets in the Crown Cathedral, with a rotating mayoral seat and a citizen-assembly for major laws.
# - Economy: Powered by solar harvest, ice mining, and advanced biotechnologies; major districts specialize in energy storage, life-support tech, and orbital logistics support.
# - People and culture: The Lunars (often called Lunari) prize transparency, art in light and shadow, and engineering precision. Public spaces emphasize walkable plazas and vertical farms.
# - Notable landmarks:
#   - Crown Cathedral: The symbolic heart of governance and the tallest structure in Lunara Prime.
#   - Solstice Gate: A shimmering arch that marks the main entrance to the city proper.
#   - Iceheart Vault: A security and archive complex carved into a sheltered crater floor.
#   - Starlight Market: A bustling outdoor bazaar with zero-gravity stalls and luminescent art.
# - Vibe: A sunlit citadel of science and governance, balanced between citizen-led civics and apace corporate orbital services.
#
# If you’d like, I can tailor Lunara Prime to a particular mood—utopian, corporate-dominated, militarized, or haunted by ancient lunar mysteries.

# %% [markdown]
# ## Image input

# %%
from ipywidgets import FileUpload
from IPython.display import display

uploader = FileUpload(accept='.png', multiple=False)
display(uploader)
# Out:
# FileUpload(value=(), accept='.png', description='Upload')

# %%
print(uploader.value)
# Out:
# ({'name': 'food.png', 'type': 'image/png', 'size': 49183, 'content': <memory at 0x00000274D42AE5C0>, 'last_modified': datetime.datetime(2026, 7, 21, 7, 7, 52, 49000, tzinfo=datetime.timezone.utc)},)

# %%
import base64

# Get the first (and only) uploaded file dict
uploaded_file = uploader.value[0]

# This is a memoryview
content_mv = uploaded_file["content"]

# Convert memoryview -> bytes
img_bytes = bytes(content_mv)  # or content_mv.tobytes()

# Now base64 encode
img_b64 = base64.b64encode(img_bytes).decode("utf-8")

# %%
multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this capital"},
    {"type": "image", "base64": img_b64, "mime_type": "image/png"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Nice image you shared. It evokes a breakfast motif—egg yolk, toast, greens—so I’ve built a capital around that idea. Here’s a complete portrait of the city I imagine from that emblem:
#
# Name and vibe
# - Name: Ovum Prime
# - Status: Capital of the Verdant Concord, a networked federation of agro-worlds that share water, seeds, and solar power.
# - Core idea: A city built to nourish a civilization that tasks itself with ecological stewardship and high-tech farming at scale.
#
# Geography and layout
# - Central motif: A circular, sunlit core city—the “Yolk”—surrounded by concentric districts that form a radiant wheel. The emblem’s yolk represents the energy source at the city’s heart.
# - Outer ring: The “Crust”—fortified residential and commercial zones with shell-like arcs and latticework façades.
# - Intermediate belts: The “Verdant Belt”—terraced parks, vertical forests, and biodomes that feed the city and regulate climate.
# - Promontory gateway: The “Pan Gate,” a wedge-shaped gateway district perched on a bluff, reminiscent of a toasted slice breaking a circle.
#
# Architecture
# - Aesthetics: Buildings mimic eggshell textures—smooth, pale ceramic exteriors with honeycomb balconies. At night, warm amber and saffron lights glow along the curves.
# - District silhouettes: The Core is a geodesic hub with a towering “Yolkspire.” Surrounding towers taper like slices of bread, giving the city a gentle, rounded skyline.
# - Green integration: Every block has micro-terraces, hydroponic gardens, and air-cooled courtyards to keep temperatures comfortable and air fresh.
#
# Government and society
# - Ruling model: A rotating council called the Custodians of Dawn, elected to six-month terms. A rotating “First Keeper” oversees energy and food security for the entire Concord.
# - Citizens and roles: People are known as Verdants. Many work in agro-tech, seed vault management, and urban farming, but there are also scientists, engineers, and artists who keep the city thriving.
# - Festivals: Breakfast Day (celebrating the city’s nourishment heritage) and the Dawn Market (a biweekly dawn-to-dusk market where farmers and makers trade in seeds, crops, and biotech novelties).
#
# Economy and technology
# - Main industries: Solar energy harvesters, biodome agriculture, seed preservation and cloning technologies, and food distribution networks that eliminate waste.
# - Key tech: Gravity-reservoir towers for water and light; autonomous urban farming drones; algae-derived bio-fuels; advanced climate-control domes.
# - Trade: Exports of drought-resistant crops, gourmet botanicals, and portable hydroponic kits for outlying colonies.
#
# Culture and daily life
# - Daily rhythm: Dawn begins with the Harvest Light festival as markets open; mid-morning neighborhoods brim with farmers’ markets; evenings glow with soft lanterns along promenades.
# - Food culture: A culinary identity built around fresh produce, fermented foods, and seed-based diets. Street stalls serve “yolk bowls” and toasted flatbreads with herb oils.
# - Arts: Light-and-shadow installations in public squares, music that scales with air quality, and garden-themed museums that celebrate plant genetics and culinary history.
#
# Landmarks and districts
# - The Yolkspire: A tall, shimmering tower that houses the city’s energy core and a public observatory.
# - Pan Gate: A sculpted gateway district with a broad arch and public markets beneath, designed to resemble a slice of bread at the rim of the circle.
# - Verdant Dome Array: A ring of biodomes and vertical forests that provide food and oxygen, with public paths weaving through treetop walkways.
# - Crust District: The bustling residential belt with curved terraces, solar canopies, and art deco minerals.
# - Harvest Quarters: A micro-city within the city dedicated to experimental farming, seed vaults, and biotech labs.
#
# Potential conflicts and stories
# - Resource balance: The city must constantly adapt water use and soil health as outer farms intensify production for a growing population.
# - Climate shocks: Sudden weather perturbations test the resilience of the biodome network.
# - Political tension: Debates over seed sovereignty, AI farm assistants’ autonomy, and the pace of genetic innovation.
#
# If you’d like, I can tailor Ovum Prime further:
# - Make it darker or more utopian.
# - Shift its location (e.g., water-world, orbiting habitat, or mountain-ring city).
# - Add aliens or other species into the culture.
# - Create a travel-guide-style map description or a character-driven scene set there.
#
# Would you like a different mood or name, or should I flesh out a short scene set in Ovum Prime?

# %% [markdown]
# ## Audio input

# %%
import sounddevice as sd
from scipy.io.wavfile import write
import base64
import io
import time
from tqdm import tqdm

# Recording settings
duration = 5  # seconds
sample_rate = 44100

print("Recording...")
audio = sd.rec(int(duration * sample_rate), samplerate=sample_rate, channels=1)
# Progress bar for the duration
for _ in tqdm(range(duration * 10)):   # update 10× per second
    time.sleep(0.1)
sd.wait()
print("Done.")

# Write WAV to an in-memory buffer
buf = io.BytesIO()
write(buf, sample_rate, audio)
wav_bytes = buf.getvalue()

aud_b64 = base64.b64encode(wav_bytes).decode("utf-8")
# Out:
# Recording...
# 100%|██████████| 50/50 [00:05<00:00,  9.86it/s]
# Done.

# %%
agent = create_agent(
    model='gpt-audio',
)

multimodal_question = HumanMessage(content=[
    {"type": "text", "text": "Tell me about this audio file"},
    {"type": "audio", "base64": aud_b64, "mime_type": "audio/wav"}
])

response = agent.invoke(
    {"messages": [multimodal_question]}
)

print(response['messages'][-1].content)
# Out:
# Please upload the audio file, and I can help analyze it. For example, I can summarize spoken content, extract key phrases, identify languages, or detect background sounds. Go ahead and share the file, and I'll assist from there.
